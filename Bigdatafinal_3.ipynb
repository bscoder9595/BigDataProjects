# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_stop='/content/drive/MyDrive/csvFiles/pred_hashtag.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(path_stop)

# %%
df
# Out:
#                                                title  \
# 0                        افزایش نرخ های فروش «خریخت»
# 1                   روند فروش "لخزر" را اینجا ببینید
# 2                            بررسی روند فروش "غشاذر"
# 3                    بلوک 7 درصد «گنگین» عرضه می شود
# 4     تحقق سود 6 میلیارد تومانی «سنوین» در خرداد ماه
# ...                                              ...
# 2264            بررسی عملکرد «تکنار» تا پایان شهریور
# 2265           تحقق سود 18 میلیارد تومانی در «شرنگی»
# 2266       آیا از تغییرات پرتفوی «ومعادن» خبر دارید؟
# 2267                      علت رشد سود «سغرب» چه بود؟
# 2268   تحقق سود 19 میلیارد تومانی «ومهان» در مهر ماه
#
#                                                 article  prediction  \
# 0     به گزارش کدال نگر بورس24 ، شرکت  صنایع ریخته گ...         0.0
# 1     به گزارش کدال نگر بورس24 ، شرکت   صنعتی پارس خ...         1.0
# 2     به گزارش کدال نگر بورس24 ، شرکت  شیر پاستوریزه...         1.0
# ...

# %%
pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285398 sha256=f8bd9ba4949a9bd80c0712e169ba7223f43f5cef230cd178f6135caf4090dc60
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# ...

# %%
import pandas as pd
from pyspark.sql import SparkSession


spark = SparkSession.builder.getOrCreate()

spark_df = spark.createDataFrame(df)

spark_df.show()
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+
# |               title|             article|prediction|   hashtag1_filtered|            hashtag2|
# +--------------------+--------------------+----------+--------------------+--------------------+
# |افزایش نرخ های فر...|به گزارش کدال نگر...|       0.0|میباشد, نرخ, مذبو...|   نرخ, باشد., مذبور|
# |روند فروش "لخزر" ...|به گزارش کدال نگر...|       1.0|ماهه, فروش, مبلغ,...|       3, ماهه, فروش|
# |بررسی روند فروش "...|به گزارش کدال نگر...|       1.0|ماهه, فروش, مبلغ,...|       3, ماهه, فروش|
# |بلوک 7 درصد «گنگی...|به گزارش کدال نگر...|       0.0|عرضه, بورس, کارگز...|عرضه, کارگزاری, ت...|
# |تحقق سود 6 میلیار...|به گزارش کدال نگر...|       1.0|   خرداد, ارزش, بورس|      6, خرداد, کرد.|
# |تصویب افزایش سرما...|به گزارش کدال نگر...|       1.0|بورس, هیأت, مدیره...|  هیأت, مدیره, صنایع|
# |سهامداران «ثرود» ...|به گزارش کدال نگر...|       1.0|بورس, سرمایه, مسک...|سرمایه, مسکن, زاینده|
# ...

# %%
df.rename(columns={'hashtag1_filtered': 'hashtag1'}, inplace=True)

# %%
df
# Out:
#                                                title  \
# 0                        افزایش نرخ های فروش «خریخت»
# 1                   روند فروش "لخزر" را اینجا ببینید
# 2                            بررسی روند فروش "غشاذر"
# 3                    بلوک 7 درصد «گنگین» عرضه می شود
# 4     تحقق سود 6 میلیارد تومانی «سنوین» در خرداد ماه
# ...                                              ...
# 2264            بررسی عملکرد «تکنار» تا پایان شهریور
# 2265           تحقق سود 18 میلیارد تومانی در «شرنگی»
# 2266       آیا از تغییرات پرتفوی «ومعادن» خبر دارید؟
# 2267                      علت رشد سود «سغرب» چه بود؟
# 2268   تحقق سود 19 میلیارد تومانی «ومهان» در مهر ماه
#
#                                                 article  prediction  \
# 0     به گزارش کدال نگر بورس24 ، شرکت  صنایع ریخته گ...         0.0
# 1     به گزارش کدال نگر بورس24 ، شرکت   صنعتی پارس خ...         1.0
# 2     به گزارش کدال نگر بورس24 ، شرکت  شیر پاستوریزه...         1.0
# ...

# %%
import pandas as pd
import re


pattern = r'\b\d+\b'

df['hashtag1'] = df['hashtag1'].str.replace(pattern, '')

df['hashtag2'] = df['hashtag2'].str.replace(pattern, '')

df
# Out:
# <ipython-input-37-4680d2e0ec43>:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['hashtag1'] = df['hashtag1'].str.replace(pattern, '')
# <ipython-input-37-4680d2e0ec43>:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['hashtag2'] = df['hashtag2'].str.replace(pattern, '')
#                                                title  \
# 0                        افزایش نرخ های فروش «خریخت»
# 1                   روند فروش "لخزر" را اینجا ببینید
# 2                            بررسی روند فروش "غشاذر"
# 3                    بلوک 7 درصد «گنگین» عرضه می شود
# 4     تحقق سود 6 میلیارد تومانی «سنوین» در خرداد ماه
# ...                                              ...
# 2264            بررسی عملکرد «تکنار» تا پایان شهریور
# 2265           تحقق سود 18 میلیارد تومانی در «شرنگی»
# 2266       آیا از تغییرات پرتفوی «ومعادن» خبر دارید؟
# 2267                      علت رشد سود «سغرب» چه بود؟
# ...

# %%
df
# Out:
#                                                title  \
# 0                        افزایش نرخ های فروش «خریخت»
# 1                   روند فروش "لخزر" را اینجا ببینید
# 2                            بررسی روند فروش "غشاذر"
# 3                    بلوک 7 درصد «گنگین» عرضه می شود
# 4     تحقق سود 6 میلیارد تومانی «سنوین» در خرداد ماه
# ...                                              ...
# 2264            بررسی عملکرد «تکنار» تا پایان شهریور
# 2265           تحقق سود 18 میلیارد تومانی در «شرنگی»
# 2266       آیا از تغییرات پرتفوی «ومعادن» خبر دارید؟
# 2267                      علت رشد سود «سغرب» چه بود؟
# 2268   تحقق سود 19 میلیارد تومانی «ومهان» در مهر ماه
#
#                                                 article  prediction  \
# 0     به گزارش کدال نگر بورس24 ، شرکت  صنایع ریخته گ...         0.0
# 1     به گزارش کدال نگر بورس24 ، شرکت   صنعتی پارس خ...         1.0
# 2     به گزارش کدال نگر بورس24 ، شرکت  شیر پاستوریزه...         1.0
# ...

# %%
df.to_csv('/content/drive/MyDrive/csvFiles/prediction_hashtag.csv',index=False)
